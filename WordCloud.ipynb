# %% [markdown]
# <a href="https://colab.research.google.com/github/srihitha4/Climate-Actiom/blob/main/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib wordcloud
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
text_data = "Srihitha Reddy . we are happy to say that we are satisfied with the product!"

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# %%
plt.figure(figsize=(10, 5))

# %%
plt.imshow(wordcloud, interpolation='bilinear')
